# %% [markdown]
# #### Short dTotal betwee -500 and 0 at 3:45 and cover at 3:48

# %%
path = 'Results/Short_dTotal_bet_0_-500_345_cvr_348'
display_results(path)
# Out:
# gross		1548
# net		-31
# shrs		243128
# comm		1580
# trades		275
# windays		148
# losedays	118
# cps		0.6

# %% [markdown]
# #### Short dTotal betwee -500 and 0 at 3:44 and cover at 3:48

# %%
path = 'Results/Short_dTotal_bet_0_-500_344_cvr_348'
display_results(path)
# Out:
# gross		968
# net		-626
# shrs		245364
# comm		1594
# trades		277
# windays		144
# losedays	126
# cps		0.4

# %% [markdown]
# #### Short positive dTotal at 9:30 cover at 9:31

# %%
path = 'Results/Short_dTotal_greater_than_0_930_cvr_931'
display_results(path)
# Out:
# gross		1543
# net		-892
# shrs		374752
# comm		2435
# trades		430
# windays		210
# losedays	200
# cps		0.4

# %% [markdown]
# #### Buy negative dTotal at 9:30 cover at 9:31

# %%
path = 'Results/Buy_dTotal_less_that_0_930_cvr_931'
display_results(path)
# Out:
# gross		1382
# net		-632
# shrs		310090
# comm		2015
# trades		348
# windays		178
# losedays	150
# cps		0.4
